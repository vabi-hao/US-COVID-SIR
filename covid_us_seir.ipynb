# %% [markdown]
# ## Explanation of the symbols
# $S$ for the number of **s**usceptible, $I$ for the number of **i**nfectious, and $R$ for the number **r**ecovered (or immune) individuals.
#
# Between $S$ and $I$, the transition rate is $\beta$. The average number of contacts per person times the probability of disease transmission in a contact between a susceptible and an infectious subject.
#
# Between $I$ and $R$, the transition rate is $\gamma$. The rate of recovery or death - 'removal rate'. Here we simply assume that the birth rate(health babies) equals the death rate. i.e. the total population in an area remains.) If the duration of the infection is denoted $T_g$, then $\gamma = 1/T_g$, since an individual experiences one recovery in $T_g$ days.
#
#
#
# Transition rates have unit of $\dfrac 1 {day}$

# %%
# COVID-19 SEIRS model forcasting U.S.
import math
import datetime
import scipy.integrate as spi
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters
from tabulate import tabulate as tb
register_matplotlib_converters()
# generation time
Tg = 20
# infectious period
Ti = 10
Tl = 8
lamda = 0.25880504
# calculate R0
def R0Func():
    # rho is the incubation period over generation time
    rho = Tl/Tg
    lamda = 0.25880504 
    R0 = 1 + lamda * Ti + rho * (1 - rho) * pow(lamda * Ti,2)   
    return R0
R0 = R0Func()
def betaFunc(R0 = R0, Ti = Ti):
    return R0/Ti
# gamma is removal rate
def gammaFunc(Tg = Tg):
    return 1/Tg
gamma = gammaFunc()
# beta is effective contact rate
beta = 0.87
[R0,beta,gamma,beta-gamma,beta/gamma]
# Out:
# [5.1955715695056375, 0.87, 0.05, 0.82, 17.4]

# %%
# differential equations
def SEIR(inivalue, _):
    Y = np.zeros(4)
    X = inivalue
    # dS/dt
    Y[0] = - (beta * X[0] * X[2]) / N
    # dE/dt
    Y[1] = (beta * X[0] * X[2]) / N - X[1] / Tl
    # dI/dt
    Y[2] = X[1] / Tl - gamma * X[2]
    # dR/dt
    Y[3] = gamma * X[2]
    return Y
# T为传播时间
T = 200
Time = np.arange(0, T + 1)
N = 330442425
#I set the susceptible number to be 60% of the total populations. Don't know wether this is right.
I = 12
INI = (N, 0, I, 0)
# solve the system of differential equations
RES = spi.odeint(SEIR, INI, Time)

# %%
plt.figure(figsize=(10,5))
start_day_us = datetime.date(2020,2,18)
dates_us = [start_day_us + datetime.timedelta(n) for n in range(T + 1)]
plt.plot(dates_us, RES[:,0],color = 'darkblue',label = 'Susceptible')
plt.plot(dates_us, RES[:,1],color = 'orange',label = 'Exposed')
plt.plot(dates_us, RES[:,2],color = 'red',label = 'Infection')
plt.plot(dates_us, RES[:,3],color = 'green',label = 'Recovery')
plt.legend()
plt.xlabel('Date')
plt.ylabel('Number')
plt.xticks(rotation=45)
plt.grid()
plt.title('SEIR MODEL OF COVID-19 in U.S. Progression')
plt.savefig('covid_us_seir_1.pdf',bbox_inches='tight')
plt.show()

# %%
exp_model = np.exp(3.05313422)*np.exp(lamda*(np.arange(T+1)-6))
y = np.array([15,15,15,35,35,35,53,57,59,60,66,71,91,109,130,161,236,336,452,573,751,1041,1288,1712,2279,3002,3778])
plt.figure(figsize=(15,5))
plt.subplot(131)
plt.plot(dates_us, RES[:,2],color = 'red',label = 'Infection')
plt.plot(dates_us, exp_model,color = 'black',label = 'Infection_exp')
plt.legend()
plt.xlabel('Date')
plt.ylabel('Comfirmed Case')
plt.xticks(rotation=45)
plt.ylim((0, 1e8)) 
#plt.xlim((datetime.date(2020,2,18),datetime.date(2020,3,18)))
plt.grid()
plt.subplot(132)
plt.plot(dates_us, RES[:,2],color = 'red',label = 'Infection')
plt.plot(dates_us, exp_model,color = 'black',label = 'Infection_exp')
plt.plot(dates_us[0:27], y,'b*',label = 'Real')

plt.legend()
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.ylim((0, 1e4)) 
plt.xlim((datetime.date(2020,3,1),datetime.date(2020,3,21)))
plt.grid()
plt.subplot(133)
plt.plot(dates_us, RES[:,2],color = 'red',label = 'Infection')
plt.plot(dates_us, exp_model,color = 'black',label = 'Infection_exp')
plt.legend()
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.ylim((10, 1e8)) 
plt.yscale('log')
plt.xlim((datetime.date(2020,2,18),datetime.date(2020,5,14)))
plt.grid()
plt.savefig('covid_us_seir_2.pdf',bbox_inches='tight')
plt.show()

# %%
Iinf = (1-gamma/beta)*N
V = Iinf/4 - 1
SIS = Iinf/(1+V*np.exp(-(beta - gamma)*np.arange(T+1)))
tp = np.zeros((T+1,5))
tp[:,2] = np.rint(RES[:,2])
tp[:,3] = np.rint(exp_model)
tp[:,4] = np.rint(SIS)
tp = tp.tolist()
for i in range(T+1):
    tp[i][0] = datetime.date(2020,2,19)+datetime.timedelta(days = i)
    if i < y.size:
        tp[i][1] = y[i]
print(tb(tp, headers=['date', 'Real','SEIR','Exponetial','SIS'],tablefmt='orgtbl'))
# Out:
# | date       |   Real |             SEIR |       Exponetial |              SIS |
# |------------+--------+------------------+------------------+------------------|
# | 2020-02-19 |     15 |     12           |      4           |      4           |
# | 2020-02-20 |     15 |     12           |      6           |      9           |
# | 2020-02-21 |     15 |     13           |      8           |     21           |
# | 2020-02-22 |     35 |     15           |     10           |     47           |
# | 2020-02-23 |     35 |     19           |     13           |    106           |
# | 2020-02-24 |     35 |     23           |     16           |    241           |
# | 2020-02-25 |     53 |     29           |     21           |    548           |
# | 2020-02-26 |     57 |     37           |     27           |   1244           |
# | 2020-02-27 |     59 |     47           |     36           |   2825           |
# | 2020-02-28 |     60 |     60           |     46           |   6414           |
# | 2020-02-29 |     66 |     77           |     60           |  14563           |
# | 2020-03-01 |     71 |     98           |     77           |  33064           |
# | 2020-03-02 |     91 |    125           |    100           |  75061           |
# | 2020-03-03 |    109 |    160           |    130           | 170373           |
# | 2020-03-04 |    130 |    204           |    168           | 386564           |
# | 2020-03-05 |    161 |    261           |    218           | 876311           |
# | 2020-03-06 |    236 |    333           |    282           |      1.98258e+06 |
# | 2020-03-07 |    336 |    426           |    365           |      4.46533e+06 |
# | 2020-03-08 |    452 |    543           |    473           |      9.95716e+06 |
# | 2020-03-09 |    573 |    694           |    613           |      2.17253e+07 |
# | 2020-03-10 |    751 |    886           |    793           |      4.53116e+07 |
# | 2020-03-11 |   1041 |   1131           |   1028           |      8.68303e+07 |
# | 2020-03-12 |   1288 |   1445           |   1331           |      1.45582e+08 |
# | 2020-03-13 |   1712 |   1844           |   1725           |      2.07385e+08 |
# | 2020-03-14 |   2279 |   2355           |   2234           |      2.55077e+08 |
# | 2020-03-15 |   3002 |   3007           |   2894           |      2.83824e+08 |
# | 2020-03-16 |   3778 |   3840           |   3749           |      2.98648e+08 |
